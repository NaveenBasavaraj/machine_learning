# %% [markdown]
# <a href="https://colab.research.google.com/github/NaveenBasavaraj/machine_learning/blob/main/1_vector_operations.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Vector Operations
# 1. Addition
# 2. Subtraction
# 3. Multiplying a vector by a scalar
# 4. Angle between 2 vectors

# %% [markdown]
# ![Screenshot 2024-07-22 214555.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2024-07-22 214650.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2024-07-22 214806.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.set()

# %% [markdown]
# ### Plotting a vector

# %%
plt.quiver(0,0,4,5)
plt.show()

# %%
plt.quiver(0,0,4,5, scale_units='xy', angles='xy',scale=1, color='b')
plt.quiver(0,0,-3,-6, scale_units='xy', angles='xy',scale=1, color='y')
plt.xlim(-8,8)
plt.ylim(-8,8)
plt.show()

# %% [markdown]
# ### Addition

# %%
vector_1 = np.asarray([0,0,2,3])
vector_2 = np.asarray([0,0,3,-2])
sum = vector_1 + vector_2
print(sum)
# Out:
# [0 0 5 1]

# %%
plt.quiver(0,0,2,3, scale_units='xy', angles='xy',scale=1, color='b')
plt.quiver(0,0,3,-2, scale_units='xy', angles='xy',scale=1, color='y')
plt.quiver(0,0,5,1, scale_units='xy', angles='xy',scale=1, color='r') # result of sum
plt.xlim(-8,8)
plt.ylim(-8,8)
plt.show()

# %% [markdown]
# ### Subtraction

# %%
vector_1 = np.asarray([0,0,2,3])
vector_2 = np.asarray([0,0,3,-2])
difff = vector_1 - vector_2
print(difff)
# Out:
# [ 0  0 -1  5]

# %%
plt.quiver(0,0,2,3, scale_units='xy', angles='xy',scale=1, color='b')
plt.quiver(0,0,3,-2, scale_units='xy', angles='xy',scale=1, color='y')
plt.quiver(0,0,-1,5, scale_units='xy', angles='xy',scale=1, color='r') # result of diff
plt.xlim(-8,8)
plt.ylim(-8,8)
plt.show()

# %% [markdown]
# ### Multiplying a vector by scalar

# %%
vector_1 = np.asarray([0,0,2,3])
vector_2 = 2 * vector_1
print(vector_2)
# Out:
# [0 0 4 6]

# %%
plt.quiver(0,0,2,3, scale_units='xy', angles='xy',scale=1, color='b')
plt.quiver(0,0,4,6, scale_units='xy', angles='xy',scale=1, color='y')
plt.xlim(-8,8)
plt.ylim(-8,8)
plt.show()

# %%
vector_1 = np.asarray([0,0,2,3])
vector_2 = -0.5 * vector_1
print(vector_2)
# Out:
# [-0.  -0.  -1.  -1.5]

# %%
plt.quiver(0,0,2,3, scale_units='xy', angles='xy',scale=1, color='b')
plt.quiver(0,0,-1,-1.5, scale_units='xy', angles='xy',scale=1, color='y')
plt.xlim(-8,8)
plt.ylim(-8,8)
plt.show()
